# %% [markdown]
# set up a proportion: <br>
# $\frac{n1}{d1}=\frac{n2}{d2}$

# %%
n1 = 1
d1 = 2
n2 = 4
d2 = 0
if n2 ==0:
    answer = n1/d1 * d2
    print("n2 ==",answer)
elif d2==0:
    answer = n2/n1 * d1
    print("d2==",answer)
# Out:
# d2== 8.0

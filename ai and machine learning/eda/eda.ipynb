# %% [markdown]
# ## ***EDA exploratory data analysis***

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info
# Out:
# <bound method DataFrame.info of       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]>

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
index_columns =['age','bmi','children','charges']
for col in index_columns:
    plt.figure(figsize=(6,4),facecolor="#FEFEFE")
    sns.histplot(df[col],kde=True,bins=20,color="#2A00B2")
plt.show()

# %%
plt.figure(figsize=(3,4),facecolor="#F6F3F3")
sns.countplot(x= df['children'],color= '#000000')
# Out:
# <Axes: xlabel='children', ylabel='count'>

# %%
plt.figure(figsize=(3,4),facecolor="#01CCFF")
sns.countplot(x=df['sex'],color="#00FF22")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=(3,4),f)
sns.countplot(x= df['smoker'],color="#000000")
# Out:
#   Cell In[108], line 1
#     plt.figure(figsize=(3,4),f)
#                               ^
# SyntaxError: positional argument follows keyword argument

# %%
for col in index_columns:
    plt.figure(figsize=(3,4),facecolor="#FCF3F3")
    sns.boxplot(x=df[col],color="#000000")

# %% [markdown]
# ## >DATA CLEANING AND PREPROCESSSING

# %%
df_cleaned = df.copy()
df_cleaned.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df_cleaned.shape
# Out:
# (1337, 7)

# %%
df_cleaned.drop_duplicates(inplace=True)

# %%
df_cleaned.shape
# Out:
# (1337, 7)

# %%
df_cleaned.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df_cleaned.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df_cleaned['sex'].value_counts()
# Out:
# sex
# male      675
# female    662
# Name: count, dtype: int64

# %%
df_cleaned['sex']= df_cleaned['sex'].map({"female":0,"male":1})

# %%
df_cleaned
# Out:
#       age  sex     bmi  children  smoker     region      charges
# 0      19  NaN  27.900         0       1  southwest  16884.92400
# 1      18  NaN  33.770         1       0  southeast   1725.55230
# 2      28  NaN  33.000         3       0  southeast   4449.46200
# 3      33  NaN  22.705         0       0  northwest  21984.47061
# 4      32  NaN  28.880         0       0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50  NaN  30.970         3       0  northwest  10600.54830
# 1334   18  NaN  31.920         0       0  northeast   2205.98080
# 1335   18  NaN  36.850         0       0  southeast   1629.83350
# 1336   21  NaN  25.800         0       0  southwest   2007.94500
# 1337   61  NaN  29.070         0       1  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df_cleaned.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19  NaN  27.900         0    yes  southwest  16884.92400
# 1   18  NaN  33.770         1     no  southeast   1725.55230
# 2   28  NaN  33.000         3     no  southeast   4449.46200
# 3   33  NaN  22.705         0     no  northwest  21984.47061
# 4   32  NaN  28.880         0     no  northwest   3866.85520

# %%
df.value_counts()
# Out:
# age  sex     bmi     children  smoker  region     charges
# 19   male    30.590  0         no      northwest  1639.56310     2
# 18   female  38.280  0         no      southeast  1631.82120     1
# 64   female  33.800  1         yes     southwest  47928.03000    1
#              32.965  0         no      northwest  14692.66935    1
# 18   female  30.115  0         no      northeast  2203.47185     1
#                                                                 ..
# 64   female  26.885  0         yes     northwest  29330.98315    1
#              30.115  3         no      northwest  16455.70785    1
#              31.300  2         yes     southwest  47291.05500    1
#              31.825  2         no      northeast  16069.08475    1
# 63   male    28.310  0         no      northwest  13770.09790    1
# Name: count, Length: 1337, dtype: int64

# %%
df_cleaned['smoker']= df_cleaned['smoker'].map({"no":0,"yes":1})

# %%
df_cleaned
# Out:
#       age  sex     bmi  children  smoker     region      charges
# 0      19  NaN  27.900         0       1  southwest  16884.92400
# 1      18  NaN  33.770         1       0  southeast   1725.55230
# 2      28  NaN  33.000         3       0  southeast   4449.46200
# 3      33  NaN  22.705         0       0  northwest  21984.47061
# 4      32  NaN  28.880         0       0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50  NaN  30.970         3       0  northwest  10600.54830
# 1334   18  NaN  31.920         0       0  northeast   2205.98080
# 1335   18  NaN  36.850         0       0  southeast   1629.83350
# 1336   21  NaN  25.800         0       0  southwest   2007.94500
# 1337   61  NaN  29.070         0       1  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df_cleaned.rename(columns={ 
    "sex":"is_female",
    "smkoer":"is_smkoer"

},inplace= True)

# %%
df_cleaned.head()
# Out:
#         age  is_female       bmi  children  smoker      charges  \
# 0 -1.438764        NaN -0.453320 -0.908614       1  16884.92400
# 1 -1.509965        NaN  0.509621 -0.078767       0   1725.55230
# 2 -0.797954        NaN  0.383307  1.580926       0   4449.46200
# 3 -0.441948        NaN -1.305531 -0.908614       0  21984.47061
# 4 -0.513149        NaN -0.292556 -0.908614       0   3866.85520
#
#    region_northwest  region_southeast  region_southwest  bmi_category_Normal  \
# 0             False             False              True                False
# 1             False              True             False                False
# 2             False              True             False                False
# 3              True             False             False                 True
# 4              True             False             False                False
#
#    bmi_category_Overweight  bmi_category_Obese  bmi_category_Normal  \
# ...

# %%
df['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
df_cleaned = pd.get_dummies(df_cleaned,columns= ['region'],drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 df_cleaned = pd.get_dummies(df_cleaned,columns= ['region'],drop_first=True)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\reshape\encoding.py:170, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     168     raise TypeError("Input must be a list-like for parameter `columns`")
#     169 else:
# --> 170     data_to_encode = data[columns]
#     172 # validate prefixes and separator to avoid silently dropping cols
#     173 def check_len(item, name: str):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
# ...

# %%
plt.figure(figsize=(3,4))
sns.histplot(df['bmi'])
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
df_cleaned['bmi_category'] = pd.cut(
    df_cleaned['bmi'],
    bins=[0,18,24.9,34,float('inf')],
    labels= ['Underweight','Normal','Overweight','Obese']
)

# %%
df_cleaned
# Out:
#            age  is_female       bmi  children  smoker      charges  \
# 0    -1.438764        NaN -0.453320 -0.908614       1  16884.92400
# 1    -1.509965        NaN  0.509621 -0.078767       0   1725.55230
# 2    -0.797954        NaN  0.383307  1.580926       0   4449.46200
# 3    -0.441948        NaN -1.305531 -0.908614       0  21984.47061
# 4    -0.513149        NaN -0.292556 -0.908614       0   3866.85520
# ...        ...        ...       ...       ...     ...          ...
# 1333  0.768473        NaN  0.050297  1.580926       0  10600.54830
# 1334 -1.509965        NaN  0.206139 -0.908614       0   2205.98080
# 1335 -1.509965        NaN  1.014878 -0.908614       0   1629.83350
# 1336 -1.296362        NaN -0.797813 -0.908614       0   2007.94500
# 1337  1.551686        NaN -0.261388 -0.908614       1  29141.36030
#
#       region_northwest  region_southeast  region_southwest  \
# 0                False             False              True
# ...

# %%
df_cleaned['is_female']= df_cleaned['is_female'].map({"female":0,"male":1})

# %%
from sklearn.preprocessing import StandardScaler
cols = ['age','bmi','children']
scaler = StandardScaler()
df_cleaned[cols]= scaler.fit_transform(df_cleaned[cols])

# %%
df_cleaned.head()
# Out:
#         age  is_female       bmi  children  smoker      charges  \
# 0 -1.438764        NaN -0.453320 -0.908614       1  16884.92400
# 1 -1.509965        NaN  0.509621 -0.078767       0   1725.55230
# 2 -0.797954        NaN  0.383307  1.580926       0   4449.46200
# 3 -0.441948        NaN -1.305531 -0.908614       0  21984.47061
# 4 -0.513149        NaN -0.292556 -0.908614       0   3866.85520
#
#    region_northwest  region_southeast  region_southwest  bmi_category_Normal  \
# 0             False             False              True                False
# 1             False              True             False                False
# 2             False              True             False                False
# 3              True             False             False                 True
# 4              True             False             False                False
#
#    bmi_category_Overweight  bmi_category_Obese  bmi_category_Normal  \
# ...

# %%
cat_features = [
    'is_female', 'is_smoker',
    'region_northwest', 'region_southeast', 'region_southwest',
    'bmi_category_Normal', 'bmi_category_Overweight', 'bmi_category_Obese'
]

# %%
from scipy.stats import chi2_contingency
import pandas as pd

alpha = 0.05

df_cleaned['charges_bin'] = pd.qcut(df_cleaned['charges'], q=4, labels=False)
chi2_results = {}

for col in cat_features:
    contingency = pd.crosstab(df_cleaned[col], df_cleaned['charges_bin'])
    chi2_stat, p_val = chi2_contingency(contingency)
    decision = 'Reject Null (Keep Feature)' if p_val < alpha else 'Accept Null (Drop Feature)'
    chi2_results[col] = {
        'chi2_statistic': chi2_stat,
        'p_value': p_val,
        'Decision': decision
    }

chi2_df = pd.DataFrame(chi2_results).T
chi2_df = chi2_df.sort_values(by='p_value')
chi2_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[137], line 11
#       9 for col in cat_features:
#      10     contingency = pd.crosstab(df_cleaned[col], df_cleaned['charges_bin'])
# ---> 11     chi2_stat, p_val = chi2_contingency(contingency)
#      12     decision = 'Reject Null (Keep Feature)' if p_val < alpha else 'Accept Null (Drop Feature)'
#      13     chi2_results[col] = {
#      14         'chi2_statistic': chi2_stat,
#      15         'p_value': p_val,
#      16         'Decision': decision
#      17     }
#
# File ~\AppData\Roaming\Python\Python312\site-packages\scipy\stats\contingency.py:321, in chi2_contingency(observed, correction, lambda_, method)
#     319     raise ValueError("All values in `observed` must be nonnegative.")
#     320 if observed.size == 0:
# --> 321     raise ValueError("No data; `observed` has size 0.")
# ...

# %%
final_df = df_cleaned[['age','is_female','charges','region_southeast','bmi_category_Obese']]
final_df
# Out:
#            age  is_female      charges  region_southeast  bmi_category_Obese  \
# 0    -1.438764        NaN  16884.92400             False               False
# 1    -1.509965        NaN   1725.55230              True               False
# 2    -0.797954        NaN   4449.46200              True               False
# 3    -0.441948        NaN  21984.47061             False               False
# 4    -0.513149        NaN   3866.85520             False               False
# ...        ...        ...          ...               ...                 ...
# 1333  0.768473        NaN  10600.54830             False               False
# 1334 -1.509965        NaN   2205.98080             False               False
# 1335 -1.509965        NaN   1629.83350              True                True
# 1336 -1.296362        NaN   2007.94500             False               False
# 1337  1.551686        NaN  29141.36030             False               False
#
#       bmi_category_Obese
# ...

# %%
df_cleaned
# Out:
#            age  is_female       bmi  children  smoker      charges  \
# 0    -1.438764        NaN -0.453320 -0.908614       1  16884.92400
# 1    -1.509965        NaN  0.509621 -0.078767       0   1725.55230
# 2    -0.797954        NaN  0.383307  1.580926       0   4449.46200
# 3    -0.441948        NaN -1.305531 -0.908614       0  21984.47061
# 4    -0.513149        NaN -0.292556 -0.908614       0   3866.85520
# ...        ...        ...       ...       ...     ...          ...
# 1333  0.768473        NaN  0.050297  1.580926       0  10600.54830
# 1334 -1.509965        NaN  0.206139 -0.908614       0   2205.98080
# 1335 -1.509965        NaN  1.014878 -0.908614       0   1629.83350
# 1336 -1.296362        NaN -0.797813 -0.908614       0   2007.94500
# 1337  1.551686        NaN -0.261388 -0.908614       1  29141.36030
#
#       region_northwest  region_southeast  region_southwest  \
# 0                False             False              True
# ...
